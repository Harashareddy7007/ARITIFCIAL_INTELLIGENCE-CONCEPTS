# %%
# NLP Text Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import string
import nltk

# %%
data = {

  "text": [

    "I love working with data and statistics",

    "Data visualization helps understand trends",

    "Data analysis improves business decisions",

    "Machine learning models can predict outcomes",

    "Training models requires a lot of data",

    "Supervised learning uses labeled data",

    "AI is transforming industries rapidly",

    "Artificial intelligence powers smart assistants",

    "AI systems can automate complex tasks",

    "Machine learning improves recommendation systems",

    "Data science combines statistics and programming",

    "Artificial intelligence enables self driving cars"

  ],

   

  "label": [

    "data_science",

    "data_science",

    "data_science",

    "machine_learning",

    "machine_learning",

    "machine_learning",

    "artificial_intelligence",

    "artificial_intelligence",

    "artificial_intelligence",

    "machine_learning",

    "data_science",

    "artificial_intelligence"

  ]

}

df = pd.DataFrame(data)
df
# Out:
#                                                  text                    label
# 0             I love working with data and statistics             data_science
# 1          Data visualization helps understand trends             data_science
# 2           Data analysis improves business decisions             data_science
# 3        Machine learning models can predict outcomes         machine_learning
# 4              Training models requires a lot of data         machine_learning
# 5               Supervised learning uses labeled data         machine_learning
# 6               AI is transforming industries rapidly  artificial_intelligence
# 7     Artificial intelligence powers smart assistants  artificial_intelligence
# 8               AI systems can automate complex tasks  artificial_intelligence
# 9    Machine learning improves recommendation systems         machine_learning
# 10   Data science combines statistics and programming             data_science
# 11  Artificial intelligence enables self driving cars  artificial_intelligence

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
df["clean_text"] = df["text"].str.lower()
df
# Out:
#                                                  text  \
# 0             I love working with data and statistics
# 1          Data visualization helps understand trends
# 2           Data analysis improves business decisions
# 3        Machine learning models can predict outcomes
# 4              Training models requires a lot of data
# 5               Supervised learning uses labeled data
# 6               AI is transforming industries rapidly
# 7     Artificial intelligence powers smart assistants
# 8               AI systems can automate complex tasks
# 9    Machine learning improves recommendation systems
# 10   Data science combines statistics and programming
# 11  Artificial intelligence enables self driving cars
#
#                                                 label  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                            clean_text
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars

# %%
df["clean_text"]=df["clean_text"].str.replace(f" [{string.punctuation}]", "", regex=True)
df.head()
# Out:
#                                            text  \
# 0       I love working with data and statistics
# 1    Data visualization helps understand trends
# 2     Data analysis improves business decisions
# 3  Machine learning models can predict outcomes
# 4        Training models requires a lot of data
#
#                                           label  \
# 0       i love working with data and statistics
# 1    data visualization helps understand trends
# 2     data analysis improves business decisions
# 3  machine learning models can predict outcomes
# 4        training models requires a lot of data
#
#                                      clean_text
# 0       i love working with data and statistics
# 1    data visualization helps understand trends
# 2     data analysis improves business decisions
# 3  machine learning models can predict outcomes
# 4        training models requires a lot of data

# %%
df["tokens"]=df["clean_text"].apply(word_tokenize)
df
# Out:
#                                                  text  \
# 0             I love working with data and statistics
# 1          Data visualization helps understand trends
# 2           Data analysis improves business decisions
# 3        Machine learning models can predict outcomes
# 4              Training models requires a lot of data
# 5               Supervised learning uses labeled data
# 6               AI is transforming industries rapidly
# 7     Artificial intelligence powers smart assistants
# 8               AI systems can automate complex tasks
# 9    Machine learning improves recommendation systems
# 10   Data science combines statistics and programming
# 11  Artificial intelligence enables self driving cars
#
#                                                 label  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                            clean_text  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                                tokens
# 0     [i, love, working, with, data, and, statistics]
# 1    [data, visualization, helps, understand, trends]
# 2     [data, analysis, improves, business, decisions]
# 3   [machine, learning, models, can, predict, outc...
# 4      [training, models, requires, a, lot, of, data]
# 5         [supervised, learning, uses, labeled, data]
# 6         [ai, is, transforming, industries, rapidly]
# 7   [artificial, intelligence, powers, smart, assi...
# 8        [ai, systems, can, automate, complex, tasks]
# 9   [machine, learning, improves, recommendation, ...
# 10  [data, science, combines, statistics, and, pro...
# 11  [artificial, intelligence, enables, self, driv...

# %%
stop_words = set(stopwords.words("english"))
df["tokens"] = df["tokens"].apply(lambda x: [word for word in x if word not in stop_words])
df
# Out:
#                                                  text  \
# 0             I love working with data and statistics
# 1          Data visualization helps understand trends
# 2           Data analysis improves business decisions
# 3        Machine learning models can predict outcomes
# 4              Training models requires a lot of data
# 5               Supervised learning uses labeled data
# 6               AI is transforming industries rapidly
# 7     Artificial intelligence powers smart assistants
# 8               AI systems can automate complex tasks
# 9    Machine learning improves recommendation systems
# 10   Data science combines statistics and programming
# 11  Artificial intelligence enables self driving cars
#
#                                                 label  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                            clean_text  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                                tokens
# 0                   [love, working, data, statistics]
# 1    [data, visualization, helps, understand, trends]
# 2     [data, analysis, improves, business, decisions]
# 3      [machine, learning, models, predict, outcomes]
# 4             [training, models, requires, lot, data]
# 5         [supervised, learning, uses, labeled, data]
# 6             [ai, transforming, industries, rapidly]
# 7   [artificial, intelligence, powers, smart, assi...
# 8             [ai, systems, automate, complex, tasks]
# 9   [machine, learning, improves, recommendation, ...
# 10  [data, science, combines, statistics, programm...
# 11  [artificial, intelligence, enables, self, driv...

# %%
lemmatizer = WordNetLemmatizer()
df["lemma"]=df["tokens"].apply(lambda words:[lemmatizer.lemmatize(w) for w in words])
df
# Out:
#                                                  text  \
# 0             I love working with data and statistics
# 1          Data visualization helps understand trends
# 2           Data analysis improves business decisions
# 3        Machine learning models can predict outcomes
# 4              Training models requires a lot of data
# 5               Supervised learning uses labeled data
# 6               AI is transforming industries rapidly
# 7     Artificial intelligence powers smart assistants
# 8               AI systems can automate complex tasks
# 9    Machine learning improves recommendation systems
# 10   Data science combines statistics and programming
# 11  Artificial intelligence enables self driving cars
#
#                                                 label  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                            clean_text  \
# 0             i love working with data and statistics
# 1          data visualization helps understand trends
# 2           data analysis improves business decisions
# 3        machine learning models can predict outcomes
# 4              training models requires a lot of data
# 5               supervised learning uses labeled data
# 6               ai is transforming industries rapidly
# 7     artificial intelligence powers smart assistants
# 8               ai systems can automate complex tasks
# 9    machine learning improves recommendation systems
# 10   data science combines statistics and programming
# 11  artificial intelligence enables self driving cars
#
#                                                tokens  \
# 0                   [love, working, data, statistics]
# 1    [data, visualization, helps, understand, trends]
# 2     [data, analysis, improves, business, decisions]
# 3      [machine, learning, models, predict, outcomes]
# 4             [training, models, requires, lot, data]
# 5         [supervised, learning, uses, labeled, data]
# 6             [ai, transforming, industries, rapidly]
# 7   [artificial, intelligence, powers, smart, assi...
# 8             [ai, systems, automate, complex, tasks]
# 9   [machine, learning, improves, recommendation, ...
# 10  [data, science, combines, statistics, programm...
# 11  [artificial, intelligence, enables, self, driv...
#
#                                                 lemma
# 0                    [love, working, data, statistic]
# 1      [data, visualization, help, understand, trend]
# 2      [data, analysis, improves, business, decision]
# 3        [machine, learning, model, predict, outcome]
# 4              [training, model, requires, lot, data]
# 5           [supervised, learning, us, labeled, data]
# 6               [ai, transforming, industry, rapidly]
# 7   [artificial, intelligence, power, smart, assis...
# 8               [ai, system, automate, complex, task]
# 9   [machine, learning, improves, recommendation, ...
# 10   [data, science, combine, statistic, programming]
# 11  [artificial, intelligence, enables, self, driv...
